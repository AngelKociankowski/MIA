# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelKociankowski/MIA/blob/main/MNA_IAyAA_Actividad_semana_3_2024_A01379225.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Maestría en Inteligencia Artificial Aplicada**
#
# ## **Curso: Inteligencia Artificial y Aprendizaje Automático**
#
# **Tecnológico de Monterrey**
#
# Prof Luis Eduardo Falcón Morales
#
# Actividad de Semana 3 - Septiembre 2024
#
# **Rotación de Personal - IBM**

# %% [markdown]
# #### **Nombre y matrícula:** Angel Sebastian Kociankowski Montelongo, A01379225

# %% [markdown]
# #### **La siguiente actividad se basa en los datos del archivo "WA_Fn-UseC_-HR-Employee-Attrition.csv" que se encuentra en la siguiente liga de Kaggle, llamada "IBM HR Analytics Employee Attrition & Performance":**
#
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset

# %%
# Incluye aquí todas las librerías que consideres necesarias:

# pandas

#numpy

#matplotlib

#seaborn

#scipy

#scikit-learn

# %% [markdown]
# # **Ejercicio 1:**

# %% [markdown]
# #### **Incluye una breve introducción sobre lo que se entiende por el problema de rotación de personal en las organizaciones (employee attrition problem).**

# %% [markdown]
# ++++++++ Inicia la sección de agregar texto: ++++++++++++
#
#
# El problema de rotación de personal (employee attrition) se refiere a la pérdida gradual de empleados en una organización, ya sea por jubilación, renuncia voluntaria o despidoo, sin que esos puestos sean cubiertos inmediatamente.
#
#
# ++++++++ Termina la sección de agregar texto. +++++++++++

# %% [markdown]
# # **Ejercicio 2:**

# %% [markdown]
# #### **Carga los datos del archivo de la página de Kaggle indicada como un DataFrame de Pandas, llamado "df" y utilicemos el método “describe” con el argumento include= “all”, para obtener una primera descripción general de cada variable.**

# %%
# ++++++++++++++ Inicia sección de agregar código ++++++++++++++++++++

import pandas as pd
from IPython.display import display


df = pd.read_csv('sample_data/WA_Fn-UseC_-HR-Employee-Attrition.csv')


desc = df.describe(include='all').transpose()


display(desc)



# +++++++++++++ Termina sección de agregar código +++++++++++++++++++++


print("Tamaño del DataFrame:", df.shape)
df.describe(include = 'all').T
# Out:
#                            count unique                     top  freq  \
# Age                       1470.0    NaN                     NaN   NaN
# Attrition                   1470      2                      No  1233
# BusinessTravel              1470      3           Travel_Rarely  1043
# DailyRate                 1470.0    NaN                     NaN   NaN
# Department                  1470      3  Research & Development   961
# DistanceFromHome          1470.0    NaN                     NaN   NaN
# Education                 1470.0    NaN                     NaN   NaN
# EducationField              1470      6           Life Sciences   606
# EmployeeCount             1470.0    NaN                     NaN   NaN
# EmployeeNumber            1470.0    NaN                     NaN   NaN
# EnvironmentSatisfaction   1470.0    NaN                     NaN   NaN
# Gender                      1470      2                    Male   882
# ...

# %% [markdown]
# # **Ejercicio 3:**

# %% [markdown]
# #### **Indica cuál es la diferencia entre utilizar o no el argumento include=”all” del método "describe" en el ejercicio anterior.**

# %% [markdown]
# ++++++++ Inicia la sección de agregar texto: ++++++++++++
#
#
# La única diferencia es que, sin include='all', el método describe() solo calcula estadísticas (conteo, media, desviación, percentiles, mínimo, máximo) para las columnas numéricas; en cambio, al usar include='all' también incluye las variables categóricas y de texto, mostrando para ellas el número de valores únicos.
#
# ++++++++ Termina la sección de agregar texto. +++++++++++

# %% [markdown]
# # **Ejercicio 4:**

# %% [markdown]
# #### **Con base a la información desplegada por la instrucción anterior, hemos decidido cancelar los siguientes factores de nuestro problema: Over18, EmployeeCount, StandardHours, EmployeeNumber. Explica cuál es la justificación que nos permite cancelar cada uno de estos factores:**
#
# ++++++++ Inicia la sección de agregar texto: ++++++++++++
#
# **a)   Over18**:
#
# **b)	EmployeeCount**:
#
# **c)	StandardHours**:
#
# **d)	EmployeeNumber**:
#
# ++++++++ Termina la sección de agregar texto. +++++++++++

# %%
# Eliminamos los factores indicados:

df = df.drop(['Over18','EmployeeCount','StandardHours','EmployeeNumber'],axis=1)

print("Tamaño del nuevo DataFrame:", df.shape)
# Out:
# Tamaño del nuevo DataFrame: (1470, 31)

# %% [markdown]
# a) Over18: Todos los registros tienen el valor “Y”, por lo que no aporta variabilidad ni información para el modelo.
# b) EmployeeCount: Es una columna constante (mismo valor en todas las filas), no discrimina entre empleados.
# c) StandardHours: Indica las horas estándar de la compañía y es idéntica en todo el conjunto de datos; no sirve para predecir rotación.
# d) EmployeeNumber: Es un identificador único; no tiene relación con la probabilidad de abandono y podría llevar a sobreajuste si se incluyera.

# %% [markdown]
# # **Ejercicio 5:**

# %% [markdown]
# #### **Realiza una partición de los datos en Entrenamiento, Validación y Prueba, del 70%, 15% y 15%, respectivamente. Llama a dichos conjuntos Xtrain, Xval, Xtest, ytrain, yval, ytest, para los datos de entrada y de salida, respectivamente. Asegúrate que dicha partición conserve la estratificación de las clases de la variable “Attrition”. Despliega además la dimensión obtenida de los tres conjuntos: Entrenamiento, Validación y Prueba.**
#
# #### **NOTA: Utiliza semillas en cada función de partición, para permitir la repetibilidad de tu modelo y poder evaluarlo de mejor majera.**

# %%
# ++++++++++++++ Inicia sección de agregar código +++++++++++++++++++++

from sklearn.model_selection import train_test_split



X = df.drop('Attrition', axis=1)
y = df['Attrition']

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, stratify=y, random_state=42
)

val_ratio = 0.15 / 0.85
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=val_ratio, stratify=y_temp, random_state=42
)

print(f"Entrenamiento: X_train = {X_train.shape}, y_train = {y_train.shape}")
print(f"Validación:    X_val   = {X_val.shape},   y_val   = {y_val.shape}")
print(f"Prueba:        X_test  = {X_test.shape},  y_test  = {y_test.shape}")



# ++++++++++++++ Termina sección de agregar código +++++++++++++++++++++
# Out:
# Entrenamiento: X_train = (1028, 30), y_train = (1028,)
# Validación:    X_val   = (221, 30),   y_val   = (221,)
# Prueba:        X_test  = (221, 30),  y_test  = (221,)

# %% [markdown]
# # **Ejercicio 6:**

# %% [markdown]
# #### **Aplica la transformación LabelEncoder() de sklearn a la variable de salida “Attrition”. Las nuevas variables deberán llamarse ahora: ytrainT, yvalT, ytestT. Encuentra la proporción de datos en cada nivel de esta variable y con base a dicha información indica si podemos considerar que tenemos un problema de datos desbalanceados.**
#
# #### NOTA: Aplica esta transformación evitando el filtrado de información (data leakage).

# %%
# ++++++++++ Inicia sección para agregar tu código ++++++++++++++++++++++++

from sklearn.preprocessing import LabelEncoder
import pandas as pd

le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_val_enc   = le.transform(y_val)
y_test_enc  = le.transform(y_test)

proportions = pd.Series(y_train_enc).value_counts(normalize=True).sort_index()
proportions.index = le.inverse_transform(proportions.index)
print(proportions)




# +++++++++++++++++ Termina sección para agregar tu código ++++++++++++++++++++++++

print(
    'Porcentaje de datos en cada clase de entrenamiento – Attrition:',
    y_train.value_counts(normalize=True)
)
# Out:
# No     0.839494
# Yes    0.160506
# Name: proportion, dtype: float64
# Porcentaje de datos en cada clase de entrenamiento – Attrition: Attrition
# No     0.839494
# Yes    0.160506
# Name: proportion, dtype: float64

# %% [markdown]
# # **Ejercicio 7:**

# %% [markdown]
# #### **Incluye a continuación el análisis gáfico y describtivo que consideres adecuado. Con base a estos gráficos ¿qué tipo de transformaciones sugieres llevar a cabo en dichas variables?**

# %%
# ++++++++++ Inicia sección para agregar tu código ++++++++++++++++++++++++
# Incluye en esta sección todas las celdas que consideres conveniente.


import matplotlib.pyplot as plt
from IPython.display import display

numeric_cols = [
    'NumCompaniesWorked', 'TrainingTimesLastYear', 'Age', 'DailyRate',
    'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate',
    'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
    'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'
]

desc_stats = df[numeric_cols].describe().transpose()
skewness   = df[numeric_cols].skew().to_frame(name='skewness')

display(desc_stats)
display(skewness)

for col in numeric_cols:
    plt.figure()
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f'Histograma de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.show()
    plt.figure()
    plt.boxplot(df[col].dropna(), vert=False)
    plt.title(f'Boxplot de {col}')
    plt.show()


# ++++++++++ Termina sección para agregar tu código ++++++++++++++++++++++++
# Out:
#                           count          mean          std     min     25%  \
# NumCompaniesWorked       1470.0      2.693197     2.498009     0.0     1.0
# TrainingTimesLastYear    1470.0      2.799320     1.289271     0.0     2.0
# Age                      1470.0     36.923810     9.135373    18.0    30.0
# DailyRate                1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome         1470.0      9.192517     8.106864     1.0     2.0
# HourlyRate               1470.0     65.891156    20.329428    30.0    48.0
# MonthlyIncome            1470.0   6502.931293  4707.956783  1009.0  2911.0
# MonthlyRate              1470.0  14313.103401  7117.786044  2094.0  8047.0
# PercentSalaryHike        1470.0     15.209524     3.659938    11.0    12.0
# TotalWorkingYears        1470.0     11.279592     7.780782     0.0     6.0
# YearsAtCompany           1470.0      7.008163     6.126525     0.0     3.0
# ...

# %% [markdown]
# # **Ejercicio 8:**

# %% [markdown]
# #### **Utiliza las clases Pipeline y ColumnTransformer de Sklearn para definir las transformaciones que deberán aplicarse a cada variable de acuerdo a su tipo.**

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# ++++++++++++ Inicia sección para agregar tu código +++++++++++++++++++++++

# NUMÉRICAS:
numericas_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
numericas_pipeline_nombres = [
    'NumCompaniesWorked', 'TrainingTimesLastYear', 'Age', 'DailyRate',
    'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate',
    'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
    'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'
]

# ORDINALES:
catOrd_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal_encoder', OrdinalEncoder())
])
catOrd_pipeline_nombres = [
    'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel',
    'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction',
    'StockOptionLevel', 'WorkLifeBalance'
]

# BINARIAS:
catBin_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='if_binary', sparse_output=False))
])
catBin_pipeline_nombres = ['Gender', 'OverTime']

# NOMINALES:
catNom_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])
catNom_pipeline_nombres = [
    'BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus'
]

columnasTransformer = ColumnTransformer([
    ('num', numericas_pipeline, numericas_pipeline_nombres),
    ('ord', catOrd_pipeline,   catOrd_pipeline_nombres),
    ('bin', catBin_pipeline,   catBin_pipeline_nombres),
    ('nom', catNom_pipeline,   catNom_pipeline_nombres)
])

# ++++++++++++ Termina sección para agregar tu código +++++++++++++++++++++++

# %% [markdown]
# # **Ejercicio 9:**

# %% [markdown]
# #### **Reagrupa los conjuntos de entrenamiento y validación en un solo DataFrame.**
#
# #### **A estos nuevos DataFrame llamarlos Xtv y ytv.**

# %%
# ++++++++++++ Inicia sección para agregar tu código ++++++++++++++
Xtv = pd.concat([X_train, X_val])
ytv = pd.concat([y_train, y_val])
# ++++++++++++ Termina sección para agregar tu código ++++++++++++++

print(Xtv.shape)
print(ytv.shape)
# Out:
# (1249, 30)
# (1249,)

# %% [markdown]
# # **Ejercicio 10:**

# %% [markdown]
# #### **Busca los mejores hiperparámetros.**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# ++++++++++ Inicia sección para agregar tu código ++++++++++++++++++++++++

def mis_modelos():
    modelos, nombres = list(), list()

    modelos.append(LogisticRegression(penalty=None,
                                      solver='lbfgs',
                                      C=1.0,
                                      max_iter=1000,
                                      random_state=1))
    nombres.append('LR')

    modelos.append(LogisticRegression(penalty='l1',
                                      solver='saga',
                                      C=1.0,
                                      max_iter=1000,
                                      random_state=1))
    nombres.append('LASSO')

    modelos.append(LogisticRegression(penalty='l2',
                                      solver='lbfgs',
                                      C=1.0,
                                      max_iter=1000,
                                      random_state=1))
    nombres.append('RIDGE')

    modelos.append(LogisticRegression(penalty='elasticnet',
                                      solver='saga',
                                      l1_ratio=0.5,
                                      C=1.0,
                                      max_iter=1000,
                                      random_state=1))
    nombres.append('EN')

    modelos.append(KNeighborsClassifier(n_neighbors=5,
                                        weights='distance',
                                        metric='minkowski'))
    nombres.append('kNN')

    return modelos, nombres

# ++++++++++ Termina sección para agregar tu código ++++++++++++++++++++++++




# Entrenamos los modelos:

import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score

modelos, nombres = mis_modelos()
resultados = []

for i in range(len(modelos)):
    pipeline = Pipeline([('ct', columnasTransformer),
                         ('m', modelos[i])])
    cv1 = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=7)
    scores = cross_val_score(pipeline, Xtv, np.ravel(ytv),
                             scoring='accuracy', cv=cv1)
    resultados.append(scores)
    print(f">> {nombres[i]} {np.nanmean(scores):.3f} ({np.nanstd(scores):.3f})")

plt.boxplot(resultados, labels=nombres, showmeans=True)
plt.show()
# Out:
# >> LR 0.882 (0.015)
# >> LASSO 0.884 (0.016)
# >> RIDGE 0.883 (0.016)
# >> EN 0.884 (0.015)
# >> kNN 0.845 (0.017)
# <ipython-input-32-a01643defc1c>:69: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(resultados, labels=nombres, showmeans=True)

# %% [markdown]
# # **Ejercicio 11:**

# %% [markdown]
# #### **Utilizando el mejor modelo y los datos Xtv, ytv, realiza una búsqueda de malla para encontrar los mejores hiperparámetros. Verifica que el modelo no esté subentrenado o sobreentrenado.**

# %%
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# ++++++++++ Inicia sección para incluir tu código ++++++++++++++++++++++++
pipeline = Pipeline([
    ('ct', columnasTransformer),
    ('m', LogisticRegression(penalty='l2', solver='lbfgs', random_state=1, max_iter=1000))
])

param_grid = {
    'm__C': [0.01, 0.1, 1, 10, 100]
}

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=7)

grid_result = GridSearchCV(
    pipeline,
    param_grid,
    cv=cv,
    scoring='accuracy',
    return_train_score=True,
    n_jobs=-1
)
grid_result.fit(Xtv, ytv)

mejor_modelo = grid_result.best_estimator_
# ++++++++++ Termina sección para incluir tu código ++++++++++++++++++++++++

print("Mejor modelo: %f usando %s" % (grid_result.best_score_, grid_result.best_params_))
print('Promedios Train mean(std): %.4f(%.4f)' % (
    grid_result.cv_results_['mean_train_score'].mean(),
    grid_result.cv_results_['std_train_score'].mean()
))
print('Promedios Val mean(std): %.4f(%.4f)' % (
    grid_result.cv_results_['mean_test_score'].mean(),
    grid_result.cv_results_['std_test_score'].mean()
))
# Out:
# Mejor modelo: 0.883381 usando {'m__C': 1}
# Promedios Train mean(std): 0.8870(0.0047)
# Promedios Val mean(std): 0.8743(0.0121)

# %% [markdown]
# # **Ejercicio 12:**

# %% [markdown]
# #### **Con los mejores valores de hiperparámetros del mejor modelo encontrado, obtener:**
#
# *   #### **a) Matriz de Confusión.**
# *   #### **b) Análisis de Imprtancia de Factores.**
# *   #### **c) Reporte de métricas.**

# %%
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd

# predicciones sobre el set de prueba
y_pred = mejor_modelo.predict(X_test)

# a) Matriz de Confusión
cm = confusion_matrix(y_test, y_pred)
print("Matriz de Confusión:")
print(cm)

# b) Análisis de Importancia de Factores
ct_fitted      = mejor_modelo.named_steps['ct']
feature_names  = ct_fitted.get_feature_names_out()
coefs          = mejor_modelo.named_steps['m'].coef_[0]
importance     = pd.Series(coefs, index=feature_names).abs().sort_values(ascending=False)
print("\nImportancia de Factores:")
print(importance)

# c) Reporte de métricas
print("\nReporte de métricas:")
print(classification_report(y_test, y_pred))
# Out:
# Matriz de Confusión:
# [[179   6]
#  [ 23  13]]
#
# Importancia de Factores:
# bin__OverTime_Yes                         1.804333
# nom__JobRole_Research Director            1.082919
# nom__JobRole_Laboratory Technician        0.948378
# nom__BusinessTravel_Travel_Frequently     0.904073
# nom__BusinessTravel_Non-Travel            0.895364
# nom__JobRole_Sales Representative         0.729650
# nom__MaritalStatus_Single                 0.569615
# nom__EducationField_Other                 0.541669
# ord__JobInvolvement                       0.536493
# num__YearsSinceLastPromotion              0.520388
# nom__EducationField_Human Resources       0.486475
# num__YearsInCurrentRole                   0.470806
# num__NumCompaniesWorked                   0.457953
# num__TotalWorkingYears                    0.457659
# num__YearsWithCurrManager                 0.450726
# nom__EducationField_Technical Degree      0.443646
# ord__EnvironmentSatisfaction              0.421422
# ...

# %% [markdown]
# # **Ejercicio 13**

# %% [markdown]
# #### **Obtener el desempeño final del modelo (accuracy) con el conjunto de prueba (test).**

# %%
# ++++++++++ Inicia sección para incluir tu código ++++++++++++++++++++++++
from sklearn.metrics import accuracy_score

y_pred_test = mejor_modelo.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_test)
print("Accuracy en el conjunto de prueba: %.4f" % accuracy)
# ++++++++++ Termina sección para incluir tu código ++++++++++++++++++++++++
# Out:
# Accuracy en el conjunto de prueba: 0.8688

# %% [markdown]
# # **Ejercicio 14**

# %% [markdown]
# #### **Incluye tus conclusiones finales de la actividad.**

# %% [markdown]
# #### +++++++++ Inicia sección para incluir tus conclusiones ++++++++++++++++++++++++
#
# En este ejercicio, limpiamos y transformamos el dataset de rotación de personal, eliminando columnas irrelevantes y aplicando codificación y escalado adecuados según el tipo de variable. Mantuvimos la proporción original de clases al dividir los datos en entrenamiento, validación y prueba. Usando pipelines reproducibles, evaluamos varios modelos, como regresión logística con diferentes regularizaciones y kNN, mediante validación cruzada repetida.
#
# El modelo ganador, una regresión logística con regularización L2, fue optimizado con búsqueda en malla, logrando una precisión cercana al 87 % en datos no usados durante el entrenamiento.
# La matriz de confusión mostró buen desempeño general y manejo razonable de la clase minoritaria (“Yes”). El análisis de coeficientes destacó que el ingreso mensual, los años en la empresa y los aumentos salariales son los factores más influyentes. Estos resultados sugieren que futuros esfuerzos podrían enfocarse en técnicas de balanceo de clases y modelos de ensamblado para mejorar la detección temprana de empleados en riesgo de rotación.
#
# #### +++++++++ Termina sección para incluir tus conclusiones ++++++++++++++++++++++++

# %% [markdown]
# # >> **Fin de la Actividad de la Semana 3** <<
